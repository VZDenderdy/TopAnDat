# %%
import pandas as pd

# %%
df = pd.read_csv("phds.csv")

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
plt.plot(df.std().index.tolist(), df.std().values)
plt.show()

# %%
df.std()
# Out:
# 1    0.429008
# 2    0.382717
# 3    0.346344
# 4    0.363632
# 5    0.310171
# 6    0.332574
# 7    0.326957
# dtype: float64
